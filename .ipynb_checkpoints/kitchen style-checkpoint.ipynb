# %%
import pandas as pd
import numpy as np

# %%
# get kitchen style matrix
kitchens = pd.read_csv('kitchen style - kitchens.tsv', sep='\t').set_index('kitchen')
kitchens
# Out:
#          style_1  style_2  style_3
# kitchen
# 1              1        0        0
# 2              1        0        0
# 3              0        1        0
# 4              0        1        0
# 5              0        0        1
# 6              0        0        1

# %%
# get user kitchen preference (i.e. which users liked which kitchens)
users = pd.read_csv('kitchen style - users.tsv', sep='\t').set_index('user')
users
# Out:
#       kitchen_1  kitchen_2  kitchen_3  kitchen_4  kitchen_5  kitchen_6
# user
# 1             1          1          0          1          0          1
# 2             1          1          1          1          0          0
# 3             0          0          0          1          1          0
# 4             1          1          1          1          0          1
# 5             0          0          0          1          1          1
# 6             1          1          0          0          0          0
# 7             1          0          1          1          1          1
# 8             0          0          1          1          0          0
# 9             0          1          0          0          0          0

# %%
# translate user kitchen preferences to kitchen styles preferences
user_style = users.dot(kitchens.to_numpy())
user_style.columns = kitchens.columns
user_style
# Out:
#       style_1  style_2  style_3
# user
# 1           2        1        1
# 2           2        2        0
# 3           0        1        1
# 4           2        2        1
# 5           0        1        2
# 6           2        0        0
# 7           1        2        2
# 8           0        2        0
# 9           1        0        0

# %%
# create a normalized version of the user/style matrix
user_style.div(user_style.sum(axis=1), axis=0)
# Out:
#       style_1   style_2   style_3
# user
# 1         0.5  0.250000  0.250000
# 2         0.5  0.500000  0.000000
# 3         0.0  0.500000  0.500000
# 4         0.4  0.400000  0.200000
# 5         0.0  0.333333  0.666667
# 6         1.0  0.000000  0.000000
# 7         0.2  0.400000  0.400000
# 8         0.0  1.000000  0.000000
# 9         1.0  0.000000  0.000000

# %%
# what kitchens are most similar to each other?
kitchen_similarity = users.T.dot(users)
kitchen_similarity
# Out:
#            kitchen_1  kitchen_2  kitchen_3  kitchen_4  kitchen_5  kitchen_6
# kitchen_1          5          4          3          4          1          3
# kitchen_2          4          5          2          3          0          2
# kitchen_3          3          2          4          4          1          2
# kitchen_4          4          3          4          7          3          4
# kitchen_5          1          0          1          3          3          2
# kitchen_6          3          2          2          4          2          4

# %%
# the normalized version of kitchen similarity
kitchen_mag = np.sqrt((users * users).sum())
kitchen_mag_dot = np.reshape(kitchen_mag.to_numpy(), (6, 1)).dot(np.reshape(kitchen_mag.to_numpy(), (1,6)))
kitchen_similarity / kitchen_mag_dot
# Out:
#            kitchen_1  kitchen_2  kitchen_3  kitchen_4  kitchen_5  kitchen_6
# kitchen_1   1.000000   0.800000   0.670820   0.676123   0.258199   0.670820
# kitchen_2   0.800000   1.000000   0.447214   0.507093   0.000000   0.447214
# kitchen_3   0.670820   0.447214   1.000000   0.755929   0.288675   0.500000
# kitchen_4   0.676123   0.507093   0.755929   1.000000   0.654654   0.755929
# kitchen_5   0.258199   0.000000   0.288675   0.654654   1.000000   0.577350
# kitchen_6   0.670820   0.447214   0.500000   0.755929   0.577350   1.000000

# %%
# style similarity
style_similarity = user_style.T.dot(user_style)
style_mag = np.sqrt((user_style * user_style).sum())
style_mag_dot = np.reshape(style_mag.to_numpy(), (3, 1)).dot(np.reshape(style_mag.to_numpy(), (1, 3)))
style_similarity / style_mag_dot
# Out:
#           style_1   style_2   style_3
# style_1  1.000000  0.648886  0.426401
# style_2  0.648886  1.000000  0.691714
# style_3  0.426401  0.691714  1.000000
